# %%
class Human:
  def __init__(self):
    self.name = "名前太郎"
    self.age = 29
  def printinfo(self):
    print(f"名前：{self.name}")
    print(f"年齢：{str(self.age)}")
hm = Human()
hm.printinfo()
# Out:
# 名前：名前太郎
# 年齢：29
