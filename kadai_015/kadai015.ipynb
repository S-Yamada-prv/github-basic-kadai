# %%
class Human:
  def __init__(self):
    self.name = ""
    self.age = 0
  def printinfo(self, name, age):
    self.name = name
    self.age = age
    print(f"名前：{self.name}")
    print(f"年齢：{str(self.age)}")
hm = Human()
hm.printinfo("名前太郎", 29)
# Out:
# 名前：名前太郎
# 年齢：29
