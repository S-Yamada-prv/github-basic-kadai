# %%
var=1
output=''

if (var % 3) == 0 and (var % 5) == 0:
  output = 'FizzBuzz'
elif (var % 3) == 0:
  output = 'Fizz'
elif (var % 5) == 0:
  output = 'Buzz'
else:
  output = str(var)
print(output)
# Out:
# 1
