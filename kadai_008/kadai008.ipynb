# %%
var=25
output=''

if (var % 3) == 0 and (var % 5) != 0:
  output = 'Fizz'
elif (var % 3) != 0 and (var % 5) == 0:
  output = 'Buzz'
elif (var % 3) == 0 and (var % 5) == 0:
  output = 'FizzBuzz'
else:
  output = str(var)
print(output)
# Out:
# Buzz
